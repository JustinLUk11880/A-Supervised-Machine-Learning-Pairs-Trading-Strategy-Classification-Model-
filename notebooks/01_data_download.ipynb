# %%
import sys
sys.path.insert(0, '../')

from src.data_loader import download_price_data
import pandas as pd

# %%
# Download data for KO and PEP
ticker1 = 'KO'
ticker2 = 'PEP'
start_date = '2020-01-01'
end_date = '2024-01-01'

prices1, prices2 = download_price_data(ticker1, ticker2, start_date, end_date)
print(f"{ticker1} shape: {prices1.shape}")
print(f"{ticker2} shape: {prices2.shape}")

# %%
# Save raw data
prices1.to_csv(f'../data_raw/{ticker1}.csv')
prices2.to_csv(f'../data_raw/{ticker2}.csv')
print(f"Saved {ticker1} and {ticker2} data to data_raw/")
